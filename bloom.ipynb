# %% [markdown]
# <a href="https://colab.research.google.com/github/Sleak07/bloom-lang-intro01/blob/main/bloom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 41.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.0 MB/s eta 0:00:00
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM ,set_seed

# %%
import torch
torch.set_default_tensor_type(torch.cuda.FloatTensor)

# %%
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b7")

# %%
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b7")

# %%
set_seed(11111)

# %%
text_prompt = "what is the color of sky"

# %%
input_tokens = tokenizer(text_prompt,return_tensors="pt" ).to(0)

# %%
input_tokens
# Out:
# {'input_ids': tensor([[25915,   632,   368,  9671,   461, 60614]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}

# %%
result_sample = model.generate(**input_tokens,max_length = 200,top_k =0, temperature =0.5 )

# %%
result_sample
# Out:
# tensor([[25915,   632,   368,  9671,   461, 60614,    34,     5,   603,     5,
#          78869,    15,     5,  7555,   368, 21380,  6149,     5, 78869,     4,
#              5, 48072,   368, 21380,    17,   567, 78869,     4,     5,   603,
#              5, 78869,     4,     5, 48072,   368, 21380,  5734,    17,   567,
#          78869,     4,     5,   603,     5, 78869,     4,     5, 48072,   368,
#          21380,  5734,    17,   567, 78869,     4,     5,   603,     5, 78869,
#              4,     5, 48072,   368, 21380,  5734,    17,   567, 78869,     4,
#              5,   603,     5, 78869,     4,     5, 48072,   368, 21380,  5734,
#             17,   567, 78869,     4,     5,   603,     5, 78869,     4,     5,
#          48072,   368, 21380,  5734,    17,   567, 78869,     4,     5,   603,
#              5, 78869,     4,     5, 48072,   368, 21380,  5734,    17,   567,
#          78869,     4,     5,   603,     5, 78869,     4,     5, 48072,   368,
# ...

# %%
print(tokenizer.decode(result_sample[0]))
# Out:
# what is the color of sky?"
#
# "Blue," said the boy.
#
# "Blue!" repeated the boy. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue!" repeated the boy again. "Blue!"
#
# "Blue
